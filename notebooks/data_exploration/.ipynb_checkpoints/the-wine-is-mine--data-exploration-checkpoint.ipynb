# %% [markdown]
# # Data Exploration Prototcol: Wine Quality
#
#
# This notebook demonstrates the effectivnes of the XGBoost model on the red wine wuality dataset with minimal parameter tuning.
#
# Comments and criticism welcome.
#
# From [kaggle kernels pull fkaadou/the-wine-is-mine-with-xgboost](https://www.kaggle.com/fkaadou/the-wine-is-mine-with-xgboost/)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from IPython.display import display
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Taking a look at the data

# %%
#import data into pandas dataframe
data = pd.read_csv("../../datasets/wine-quality/input/winequality-red.csv")

#display first 5 lines
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#print data properties
print('Data Shape: {}'.format(data.shape))
# Out:
# Data Shape: (1599, 12)

# %%
display(data.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None

# %%
sns.countplot(data['quality'],label="Count")

# %% [markdown]
# **Notes**
#
# * data consitsts of 11 features
#     * no missing or NaN entries.
#     * features vary in magnitude and scale $\to$ some *feature scaling* is required.
#
# Note how most wines in the dataset are of mediocre quality (5-6), with a low population of the low quality wines (3-4).
# For this analysis we will rearrange wine quality into low quality wines (<7) and high quality wines (>= 7).

# %% [markdown]
# ## Correlations
#
# Here we can see which features are correlated with the confusion matrix

# %%
plt.figure(figsize=(10,10))
corr_mat=sns.heatmap(data.corr(method='spearman'),annot=True,cbar=True,
            cmap='viridis', vmax=1,vmin=-1,
            xticklabels=data.columns,yticklabels=data.columns)
corr_mat.set_xticklabels(corr_mat.get_xticklabels(),rotation=90)
plt.savefig('correlation_matrix_with_target.png')

# %% [markdown]
# Note the following features are well correlated:
# -  citric acid and fixed acidity
# -  citric acid and volatile acidity
# -  density and fixed acidity
# -  pH and fixed acidity
# -  pH and citric acidity
#
# Notice that quality is most correlated with alcohol.
#
#
# ## Preparing the Data
#
# Relabeling wine quality:

# %%
bins = (1, 6.5, 8.5)
quality_level = ['low', 'high']

data['quality'] = pd.cut(data['quality'], bins = bins, labels = quality_level)
sns.countplot(data['quality'])

# %% [markdown]
# ### Feature extraction, scaling and splitting into train and test set.
#
# Note the use of **stratification** in the splitting: since this is a highly unbalanced dataset (fewer 'high' than 'low'), it is important to stratify the split i.e keep the proportion of classes the same in the splits.

# %%
#Extract data and label target
X = data.iloc[:,0:11]
le = LabelEncoder().fit(data['quality'])
y = le.transform(data['quality'])

X_train,X_test,y_train,y_test = train_test_split(X, y, random_state=0,stratify=y)

#Scale data
scaler = MinMaxScaler()
scaler.fit(X_train,y_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Pairplot
#
# Plots pair-wise distributions as scatterplots
#
# Some useful features
# * categorizing the distributions and scatters based on additional field can offer insights

# %%
sns.pairplot(data, hue = "quality", diag_kind='kde')

# %% [markdown]
# we can see some the correlations noted previously in the above pairplot.

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
discretizer = lambda y: lambda x: (x-x%y)

# %%
data['pH_disc'] = data["pH"].apply(discretizer(0.5))

# %%
minimal_cols = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'sulphates', 'alcohol','pH_disc']

# %%
sns.pairplot(data[minimal_cols], hue = 'pH_disc', diag_kind='kde')

# %%
minminimal_cols = ['fixed acidity', 'volatile acidity', 'residual sugar', 'alcohol','pH_disc']

# %%
sns.pairplot(data[minminimal_cols], hue = 'pH_disc', diag_kind='kde')
plt.savefig('pairplots_with_hued_kde.png')
